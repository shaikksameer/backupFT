# %%
print("sameer")
# Out:
# sameer

# %%
pip install faker
# Out:
# ...
#   Using cached Faker-16.6.0-py3-none-any.whl (1.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script faker.exe is installed in 'C:\Users\miles\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from faker import Faker
fake=Faker()

# %%
import random
arr= ["AD",
"AE",
"AF",
"AG",
"AI",
"AL",
"AM",
"AN",
"AO",
"AQ",
"AR",
"AS",
"AT",
"AU",
"AW",
"AZ",
"BA",
"BB",
"BD",
"BE",
"BF",
"BG",
"BH",
"BI",
"BJ",
"BM",
"BN",
"BO",
"BR",
"BS",
"BT",
"BV",
"BW",
"BY",
"BZ",
"CA",
"CC",
"CD",
"CF",
"CG",
"CH",
"CI",
"CK",
"CL",
"CM",
"CN",
"CO",
"CR",
"CS",
"CU",
"CV",
"CX",
"CY",
"CZ",
"DE",
"DJ",
"DK",
"DM",
"DO",
"DZ",
"EC",
"EE",
"EG",
"EH",
"ER",
"ES",
"ET",
"FI",
"FJ",
"FK",
"FM",
"FO",
"FR",
"GA",
"GB",
"GD",
"GE",
"GF",
"GH",
"GI",
"GL",
"GM",
"GN",
"GP",
"GQ",
"GR",
"GS",
"GT",
"GU",
"GW",
"GY",
"HK",
"HM",
"HN",
"HR",
"HT",
"HU",
"ID",
"IE",
"IL",
"IN",
"IO",
"IQ",
"IR",
"IS",
"IT",
"JM",
"JO",
"JP",
"KE",
"KG",
"KH",
"KI",
"KM",
"KN",
"KP",
"KR",
"KW",
"KY",
"KZ",
"LA",
"LB",
"LC",
"LI",
"LK",
"LR",
"LS",
"LT",
"LU",
"LV",
"LY",
"MA",
"MC",
"MD",
"MG",
"MH",
"MK",
"ML",
"MM",
"MN",
"MO",
"MP",
"MQ",
"MR",
"MS",
"MT",
"MU",
"MV",
"MW",
"MX",
"MY",
"MZ",
"NA",
"NC",
"NE",
"NF",
"NG",
"NI",
"NL",
"NO",
"NP",
"NR",
"NU",
"NZ",
"OM",
"PA",
"PE",
"PF",
"PG",
"PH",
"PK",
"PL",
"PM",
"PN",
"PR",
"PS",
"PT",
"PW",
"PY",
"QA",
"RE",
"RO",
"RU",
"RW",
"SA",
"SB",
"SC",
"SD",
"SE",
"SG",
"SH",
"SI",
"SJ",
"SK",
"SL",
"SM",
"SN",
"SO",
"SR",
"ST",
"SV",
"SY",
"SZ",
"TC",
"TD",
"TF",
"TG",
"TH",
"TJ",
"TK",
"TL",
"TM",
"TN",
"TO",
"TR",
"TT",
"TV",
"TW",
"TZ",
"UA",
"UG",
"UM",
"US",
"UY",
"UZ",
"VA",
"VC",
"VE",
"VG",
"VI",
"VN",
"VU",
"WF",
"WS",
"YE",
"YT",
"ZA",
"ZM",
"ZW"
]
cc=random.choice(arr)
print(cc)
# Out:
# TO

# %% [markdown]
# client_id , first_name,last_name , gender ,   phone_no ,email , passport_num , country_code , middlename

# %%
aa=0
while aa<3000:    
    client_id=fake.random_number(digits=4)
    first_name= fake.first_name()
    last_name= fake.last_name()
    gen=fake.profile()
    gender=gen["sex"]
    phone_no=fake.msisdn()
    email=fake.email()
    passport_num=fake.random_number(digits=8)
    country_code=cc
    middle_name=fake.first_name()
    print("(""\"%s\""%first_name,",","\"%s\""%last_name,",","\"%s\""%gender,",",phone_no,",","\"%s\""%email,",","\"%s\""%passport_num,",","\"%s\""%country_code,",","\"%s\""%middle_name,")",",")
    aa+=1
# Out:
# ("Andrew" , "Cordova" , "M" , 8125915044170 , "tannerscott@example.net" , "31222589" , "TO" , "Mary" ) ,
# ("Katrina" , "Cooper" , "F" , 5984633509307 , "audreyowen@example.com" , "32403830" , "TO" , "Barbara" ) ,
# ("Cynthia" , "Flowers" , "M" , 8819191978391 , "gcastillo@example.net" , "82203917" , "TO" , "Andre" ) ,
# ("Edward" , "Flores" , "M" , 1576192582355 , "hendersonscott@example.org" , "3340998" , "TO" , "Timothy" ) ,
# ("Stephen" , "Garcia" , "M" , 2860004855296 , "cmcdonald@example.com" , "73543289" , "TO" , "Edward" ) ,
# ("Brandon" , "Edwards" , "F" , 9668356770424 , "fhanson@example.org" , "48503132" , "TO" , "Shawn" ) ,
# ("Jeffrey" , "Anderson" , "M" , 8299309130776 , "ericmurray@example.com" , "91504105" , "TO" , "Shelly" ) ,
# ("Summer" , "Rosario" , "F" , 1871844199321 , "jason58@example.com" , "38240794" , "TO" , "Gary" ) ,
# ("Kevin" , "Hunt" , "F" , 0095505447466 , "jerrysmith@example.net" , "50574525" , "TO" , "Pam" ) ,
# ...

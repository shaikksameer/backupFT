# %%
import pandas as pd

# %%
df=pd.read_csv("NbaInfo.csv")
n=5

# %%
df.sample(frac=0.3)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 90    Anderson Varejao  Golden State Warriors    18.0       PF  33.0   6-11
# 265         Marc Gasol      Memphis Grizzlies    33.0        C  31.0    7-1
# 165         Tony Snell          Chicago Bulls    20.0       SF  24.0    6-7
# 124     Tyson Chandler           Phoenix Suns     4.0        C  33.0    7-1
# 202       Solomon Hill         Indiana Pacers    44.0       SF  25.0    6-7
# ..                 ...                    ...     ...      ...   ...    ...
# 353      Dorell Wright             Miami Heat    11.0       SF  30.0    6-9
# 236      Dirk Nowitzki       Dallas Mavericks    41.0       PF  37.0    7-0
# 378    Otto Porter Jr.     Washington Wizards    22.0       SF  23.0    6-8
# 227    Justin Anderson       Dallas Mavericks     1.0       SG  22.0    6-6
# 74   Jonas Valanciunas        Toronto Raptors    17.0        C  24.0    7-0
#
#      Weight     College      Salary
# ...

# %%
df["Weight"].sort_values(ascending=False)
# Out:
# 405    307.0
# 302    290.0
# 330    289.0
# Name: Weight, dtype: float64

# %%
df.nlargest(3,columns="Weight")
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 405    Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330      Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
#
#      Weight College      Salary
# 405   307.0     NaN  12100000.0
# 302   290.0     NaN   1200000.0
# 330   289.0     NaN  13500000.0

# %%
df.nsmallest(3,columns="Weight")
# Out:
#               Name               Team  Number Position   Age Height  Weight  \
# 152   Aaron Brooks      Chicago Bulls     0.0       PG  31.0    6-0   161.0
# 263   Bryce Cotton  Memphis Grizzlies     8.0       PG  23.0    6-1   165.0
# 350  Briante Weber         Miami Heat    12.0       PG  23.0    6-2   165.0
#
#                    College     Salary
# 152                 Oregon  2250000.0
# 263             Providence   700902.0
# 350  Virginia Commonwealth        NaN

# %%
df.where(df["Age"]>20)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.query("Position=='C'")
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 7       Kelly Olynyk          Boston Celtics    41.0        C  25.0    7-0
# 10   Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# 14      Tyler Zeller          Boston Celtics    44.0        C  26.0    7-0
# 23       Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
# 27        Henry Sims           Brooklyn Nets    14.0        C  26.0   6-10
# ..               ...                     ...     ...      ...   ...    ...
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 439    Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 447      Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 455     Tibor Pleiss               Utah Jazz    21.0        C  26.0    7-3
# 456      Jeff Withey               Utah Jazz    24.0        C  26.0    7-0
#
#      Weight           College      Salary
# ...

# %%
df=df.rename(mapper={"College":"College Name"},axis='columns')

# %%
df.query("College=='Texas'")
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
for i in  df.columns:
    print(i)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College Name
# Salary

# %%
l=[]
for data in  df.columns:
    s=data.replace(" ","_")
    l.append(s)
    print(s)
print(l)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College_Name
# Salary
# ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College_Name', 'Salary']

# %%
df.columns=l

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#           College_Name     Salary
# 0                Texas  7730337.0
# ...

# %%
ll=[data.replace(" ","_") for data in  df.columns ] # string Comprehensions

# %%
df.columns=ll

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#           College_Name     Salary
# 0                Texas  7730337.0
# ...

# %%
ll=[data.replace(" ","_") for data in  df.columns]

# %%
ll
# Out:
# ['Name',
#  'Team',
#  'Number',
#  'Position',
#  'Age',
#  'Height',
#  'Weight',
#  'College_Name',
#  'Salary']

# %%
# dataframe Nba 
# query (age =21 28 13)
# name column mr/mrs

# %%
df1=pd.read_csv("NbaInfo.csv",usecols=["Name","Age","Team"])

# %%
df1
# Out:
#               Name            Team   Age
# 0    Avery Bradley  Boston Celtics  25.0
# 1      Jae Crowder  Boston Celtics  25.0
# 2     John Holland  Boston Celtics  27.0
# 3      R.J. Hunter  Boston Celtics  22.0
# 4    Jonas Jerebko  Boston Celtics  29.0
# ..             ...             ...   ...
# 453   Shelvin Mack       Utah Jazz  26.0
# 454      Raul Neto       Utah Jazz  24.0
# 455   Tibor Pleiss       Utah Jazz  26.0
# 456    Jeff Withey       Utah Jazz  26.0
# 457            NaN             NaN   NaN
#
# [458 rows x 3 columns]

# %%
df1.query("Age ==21 | Age==28  | Age==13")
# Out:
#                         Name                    Team   Age
# 6              Jordan Mickey          Boston Celtics  21.0
# 17           Wayne Ellington           Brooklyn Nets  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets  21.0
# 23               Brook Lopez           Brooklyn Nets  28.0
# 24          Chris McCullough           Brooklyn Nets  21.0
# 28              Donald Sloan           Brooklyn Nets  28.0
# 38               Robin Lopez         New York Knicks  28.0
# 42              Lance Thomas         New York Knicks  28.0
# 80             Stephen Curry   Golden State Warriors  28.0
# 88         Marreese Speights   Golden State Warriors  28.0
# 97            Wesley Johnson    Los Angeles Clippers  28.0
# 115            Julius Randle      Los Angeles Lakers  21.0
# 123           Chase Budinger            Phoenix Suns  28.0
# 125           Archie Goodwin            Phoenix Suns  21.0
# 142          Darren Collison        Sacramento Kings  28.0
# ...

# %%
d=df1["Name"]

# %%
d
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
def add(d):
    # for data in d:
    return("Mr/Ms "+str(d))

# %%
add(d)
# Out:
# 'Mr/Ms 0      Avery Bradley\n1        Jae Crowder\n2       John Holland\n3        R.J. Hunter\n4      Jonas Jerebko\n           ...      \n453     Shelvin Mack\n454        Raul Neto\n455     Tibor Pleiss\n456      Jeff Withey\n457              NaN\nName: Name, Length: 458, dtype: object'

# %%
df1["Name"]=df1["Name"].apply(add)

# %%
df1
# Out:
#                     Name            Team   Age
# 0    Mr/Ms Avery Bradley  Boston Celtics  25.0
# 1      Mr/Ms Jae Crowder  Boston Celtics  25.0
# 2     Mr/Ms John Holland  Boston Celtics  27.0
# 3      Mr/Ms R.J. Hunter  Boston Celtics  22.0
# 4    Mr/Ms Jonas Jerebko  Boston Celtics  29.0
# ..                   ...             ...   ...
# 453   Mr/Ms Shelvin Mack       Utah Jazz  26.0
# 454      Mr/Ms Raul Neto       Utah Jazz  24.0
# 455   Mr/Ms Tibor Pleiss       Utah Jazz  26.0
# 456    Mr/Ms Jeff Withey       Utah Jazz  26.0
# 457            Mr/Ms nan             NaN   NaN
#
# [458 rows x 3 columns]

# %%
df1=pd.read_csv("NbaInfo.csv")
df_copy=df1.copy()

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
num=df1["College"]

def change(num):
    if num == "Florida":
        return "Bangalore"
    else:
        return num

# %%
df1["College"].apply(change)
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object

# %%
FChange=df1.at[88,"College"]

# %%
FChange
# Out:
# 'Florida'

# %%
def changeF(FChange):
    if FChange == "Florida":
        return "Bangalore"
    else:
        return FChange

# %%
df1["College"].apply(changeF)
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    NaN
#              ...
# 453               Butler
# 454                  NaN
# 455                  NaN
# 456               Kansas
# 457                  NaN
# Name: College, Length: 458, dtype: object

# %%
df_copy.drop_duplicates(subset='College', keep='first')
# Out:
#                Name                    Team  Number Position   Age Height  \
# 0     Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 1       Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 3       R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 4     Jonas Jerebko          Boston Celtics     8.0       PF  29.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 436  Damian Lillard  Portland Trail Blazers     0.0       PG  25.0    6-3
# 437   C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0    6-4
# 438    Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 440   Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 448  Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
#
#      Weight            College      Salary
# ...

# %%
df_copy
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1[df1["Name"]=="Avery Bradley"]["College"]
# Out:
# 0    Texas
# Name: College, dtype: object

# %%
df1.loc[df1[df1["Name"]=="Avery Bradley"].index[0],"College"]="Bangalore"

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0            Bangalore  7730337.0
# ...

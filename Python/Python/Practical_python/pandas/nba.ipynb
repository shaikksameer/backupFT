# %%
import pandas as pd

# %%
df=pd.read_csv("NbaInfo.csv")

# %%
df
# Out:
#               Name  WeightUser            Team  Number Position   Age Height  \
# 0    Avery Bradley          80  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder          80  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland          80  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter          80  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko          80  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...         ...             ...     ...      ...   ...    ...
# 453   Shelvin Mack          80       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto          80       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss          80       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey          80       Utah Jazz    24.0        C  26.0    7-0
# 457            NaN          80             NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
df ["Email"]="user@gmail.com"

# %%
df.insert(loc=1, column="WeightUser", value=80)

# %%
df["Age"]+4
# Out:
# 0      29.0
# 1      29.0
# 2      31.0
# 3      26.0
# 4      33.0
#        ...
# 453    30.0
# 454    28.0
# 455    30.0
# 456    30.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
df["newage"]=df["Age"]+4

# %%
(df.value_counts(subset="Team",normalize=True,dropna=False)*100)
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Atlanta Hawks             3.275109
# Boston Celtics            3.275109
# Washington Wizards        3.275109
# Utah Jazz                 3.275109
# Toronto Raptors           3.275109
# San Antonio Spurs         3.275109
# Sacramento Kings          3.275109
# Portland Trail Blazers    3.275109
# Phoenix Suns              3.275109
# Philadelphia 76ers        3.275109
# Oklahoma City Thunder     3.275109
# Miami Heat                3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Indiana Pacers            3.275109
# Houston Rockets           3.275109
# Golden State Warriors     3.275109
# Detroit Pistons           3.275109
# Denver Nuggets            3.275109
# Dallas Mavericks          3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# ...

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Name"].hasnans
# Out:
# True

# %%
df.dropna(how="any")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(how="all") # is the whole column constains nan value
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df2=df.dropna(subset=["College","Salary"])

# %%
df2
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.fillna("None")
# Out:
#               Name            Team Number Position   Age Height Weight  \
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0    6-2  180.0
# 1      Jae Crowder  Boston Celtics   99.0       SF  25.0    6-6  235.0
# 2     John Holland  Boston Celtics   30.0       SG  27.0    6-5  205.0
# 3      R.J. Hunter  Boston Celtics   28.0       SG  22.0    6-5  185.0
# 4    Jonas Jerebko  Boston Celtics    8.0       PF  29.0   6-10  231.0
# ..             ...             ...    ...      ...   ...    ...    ...
# 453   Shelvin Mack       Utah Jazz    8.0       PG  26.0    6-3  203.0
# 454      Raul Neto       Utah Jazz   25.0       PG  24.0    6-1  179.0
# 455   Tibor Pleiss       Utah Jazz   21.0        C  26.0    7-3  256.0
# 456    Jeff Withey       Utah Jazz   24.0        C  26.0    7-0  231.0
# 457           None            None   None     None  None   None   None
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# ...

# %%
df["Salary"]=df["Salary"].fillna(0)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["College"]=df["College"].fillna("None")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Salary"].hasnans
# Out:
# False

# %%
df.sort_values(by="Team",na_position="last")
# Out:
#                  Name                Team  Number Position   Age Height  \
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    6-5
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# ..                ...                 ...     ...      ...   ...    ...
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 382         John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 370      Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 317   225.0      Pittsburgh    525093.0
# ...

# %%
df.sort_values(by=["Team","Name"],ascending=False)
# Out:
#                 Name                Team  Number Position   Age Height  \
# 379   Ramon Sessions  Washington Wizards     7.0       PG  30.0    6-3
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF  23.0    6-8
# 375     Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 376  Markieff Morris  Washington Wizards     5.0       PF  26.0   6-10
# 381  Marcus Thornton  Washington Wizards    15.0       SF  29.0    6-4
# ..               ...                 ...     ...      ...   ...    ...
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 323      Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 312       Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 457              NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight       College      Salary
# 379   190.0        Nevada   2170465.0
# ...

# %%
(df.sort_values(by=["Team","Name"],ascending=[False,True])).sort_index()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 457 non-null    object
# dtypes: object(1)
# memory usage: 3.7+ KB

# %%
df["Salary"].astype(int)
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# 457          0
# Name: Salary, Length: 458, dtype: int32

# %%
df["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 457 non-null    float64
# dtypes: float64(1)
# memory usage: 3.7 KB

# %%
df["Age"]=df["Age"].fillna(0)

# %%
df["Age"]=df["Age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 30.5+ KB

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
# 457            NaN             NaN     NaN      NaN    0    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Salary"].nunique()
# Out:
# 310

# %%
df["Team"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 458 entries, 0 to 457
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 457 non-null    object
# dtypes: object(1)
# memory usage: 3.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(3), int32(1), object(5)
# memory usage: 30.5+ KB

# %%
df["Team"]=df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: category(1), float64(3), int32(1), object(4)
# memory usage: 28.7+ KB

# %%
df["Position"].nunique()
# Out:
# 5

# %%
df["Position"]=df["Position"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: category(2), float64(2), int32(2), object(3)
# memory usage: 24.0+ KB

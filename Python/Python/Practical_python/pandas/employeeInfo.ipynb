# %%
import pandas as pd

# %%
pd.read_csv("EmployeesInfo.csv",parse_dates=["Start Date","Last Login Time"])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-02-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-02-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-02-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-02-01 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-02-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-02-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-02-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-02-01 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-02-01 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df1=df=pd.read_csv("EmployeesInfo.csv")

# %%
df=pd.read_csv("EmployeesInfo.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["First Name"].hasnans
# Out:
# True

# %%
df["Gender"].hasnans
# Out:
# True

# %%
df["Start Date"]=pd.to_datetime(df["Start Date"])

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Last Login Time"]=pd.to_datetime(df["Last Login Time"])

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2023-02-01 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2023-02-01 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2023-02-01 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2023-02-01 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2023-02-01 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Senior Management"]=df["Senior Management"].astype(bool)

# %%
df["Team"]=df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.3+ KB

# %%
df["Team"].fillna("None")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df["Team"].fillna("None")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:5298, in Series.fillna(self, value, method, axis, inplace, limit, downcast)
# ...

# %%
df["Team"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Team
# Non-Null Count  Dtype
# --------------  -----
# 957 non-null    category
# dtypes: category(1)
# memory usage: 1.5 KB

# %%
df["Team"]
# Out:
# 0                 Marketing
# 1                       NaN
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: category
# Categories (10, object): ['Business Development', 'Client Services', 'Distribution', 'Engineering', ..., 'Legal', 'Marketing', 'Product', 'Sales']

# %%
cond1=df["Gender"]=='Male'
df[cond1]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 3        Jerry   Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df[df["Start Date"]>'1987-08-1']
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 993       Tina  Female  5/15/1997         3:53 PM   56450   19.040
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# louis,  senior mangemt 
# no of female, selected after 1990 
# user salary from 10,000 to 20,000

# %%
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df[(df["First Name"]=="Louise") & (df["Senior Management"]==True) ]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 441     Louise  Female  5/13/2003         9:47 AM   46666    1.886
#
#     Senior Management                  Team
# 10               True                   NaN
# 441              True  Business Development

# %%
df[(df["Gender"]=="Female" )& (df["Start Date"]>"1990-01-01")]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 6         Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 9      Frances  Female   8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# ..         ...     ...        ...             ...     ...      ...
# 975      Susan  Female   4/7/1995        10:05 PM   92436   12.467
# 982       Rose  Female   4/6/1982        10:43 AM   91411    8.639
# 990      Robin  Female  7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female  8/25/2002         5:12 AM  134505   11.051
# 993       Tina  Female  5/15/1997         3:53 PM   56450   19.040
#
#     Senior Management                  Team
# 2               False               Finance
# 6                True               Product
# ...

# %%
df[(df["Salary"]>=30000) & (df["Salary"]<=70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 6         Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 14    Kimberly  Female  1/14/1999         7:13 AM   41426   14.543
# ..         ...     ...        ...             ...     ...      ...
# 988      Alice  Female  10/5/2004         9:34 AM   47638   11.209
# 989     Justin     NaN  2/10/1991         4:58 PM   38344    3.794
# 993       Tina  Female  5/15/1997         3:53 PM   56450   19.040
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
df[df["Salary"].between(30000,70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 6         Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 14    Kimberly  Female  1/14/1999         7:13 AM   41426   14.543
# ..         ...     ...        ...             ...     ...      ...
# 988      Alice  Female  10/5/2004         9:34 AM   47638   11.209
# 989     Justin     NaN  2/10/1991         4:58 PM   38344    3.794
# 993       Tina  Female  5/15/1997         3:53 PM   56450   19.040
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
df[df["Team"].isin(["Legal","Product","Human Resources"])]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 15     Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# ..         ...     ...         ...             ...     ...      ...
# 982       Rose  Female    4/6/1982        10:43 AM   91411    8.639
# 985    Stephen     NaN   7/10/1983         8:10 PM   85668    1.909
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
#
#     Senior Management             Team
# 5               False            Legal
# 6                True          Product
# ...

# %%
df["First Name"].hasnans
# Out:
# True

# %%
df[df["First Name"].isnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female  7/20/2015        10:43 AM   45906   11.598
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 25         NaN    Male  10/8/2012         1:12 AM   37076   18.576
# 32         NaN    Male  8/21/1998         2:27 PM  122340    6.417
# 39         NaN    Male  1/29/2016         2:33 AM  122173    7.797
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 7                 NaN          Finance
# 23                NaN              NaN
# 25                NaN  Client Services
# ...

# %%
df[(df["Gender"]=="Female")& (df["Team"].isna() == False)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 987     Gloria  Female   12/8/2014         5:08 AM  136709   10.331
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
#
#     Senior Management                  Team
# 2               False               Finance
# 6                True               Product
# ...

# %%
df[df["Team"].isna() == False]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.sort_values(by="First Name",inplace=True)

# %%
df.head()
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron   Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron   Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron    NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam   Male  5/21/2011         1:45 AM   95327   15.120
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# 937             False  Client Services
# 137             False     Distribution

# %%
df[~df["First Name"].duplicated(keep='first')].head(5)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# 300       Alan    Male  6/26/1988         3:54 AM  111786    3.592
# 959     Albert    Male  9/19/1992         2:35 AM   45094    5.850
# 988      Alice  Female  10/5/2004         9:34 AM   47638   11.209
#
#     Senior Management                  Team
# 101              True             Marketing
# 137             False          Distribution
# 300              True           Engineering
# 959              True  Business Development
# 988             False       Human Resources

# %%
df[~df["First Name"].duplicated(keep="last")].head()
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN   1/22/1986         7:39 PM   63126   18.424
# 538       Adam    Male   10/8/2010         9:53 PM   45181    3.491
# 610       Alan    Male   2/17/2012        12:26 AM   41453   10.084
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 693      Alice  Female  10/16/1995         9:19 PM   92799    2.782
#
#     Senior Management             Team
# 937             False  Client Services
# 538             False  Human Resources
# 610             False          Product
# 372              True      Engineering
# 693             False            Sales

# %%
df[df.duplicated(subset="First Name",keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
df[~df.duplicated(subset=["First Name"],keep=False)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 688      Brian    Male    4/7/2007        10:47 PM   93901   17.821
# 190      Carol  Female   3/19/1996         3:39 AM   57783    9.129
# 887      David    Male   12/5/2009         8:48 AM   92242   15.407
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 495     Eugene    Male   5/24/1984        10:54 AM   81077    2.117
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 832      Keith    Male   2/12/2003         3:02 PM  120672   19.467
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# 5               False                 Legal
# ...

# %%
df.drop_duplicates(subset="First Name", keep=False)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 688      Brian    Male    4/7/2007        10:47 PM   93901   17.821
# 190      Carol  Female   3/19/1996         3:39 AM   57783    9.129
# 887      David    Male   12/5/2009         8:48 AM   92242   15.407
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 495     Eugene    Male   5/24/1984        10:54 AM   81077    2.117
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 832      Keith    Male   2/12/2003         3:02 PM  120672   19.467
# 291      Tammy  Female  11/11/1984        10:30 AM  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# 5               False                 Legal
# ...

# %%
dummy=df.set_index("First Name")

# %%
dummy.reset_index()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0        Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 1        Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 2        Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 3        Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 4         Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 995        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 996        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 997        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 998        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 999        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True        Marketing
# 2                True  Client Services
# ...

# %%
df.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
df.loc[[1,2,3],"First Name":"Salary"]
# Out:
#   First Name  Gender Start Date Last Login Time  Salary
# 1     Thomas    Male  3/31/1996         6:53 AM   61933
# 2      Maria  Female  4/23/1993        11:17 AM  130590
# 3      Jerry    Male   3/4/2005         1:00 PM  138705

# %%
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
df[["First Name"]].iloc[1:4,-1]
# Out:
# 327    Aaron
# 440    Aaron
# 937    Aaron
# Name: First Name, dtype: object

# %%
df.rename(mapper={"First Name":"Name"},axis="columns")
# Out:
#       Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101  Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327  Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440  Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937  Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137   Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..     ...     ...        ...             ...     ...      ...
# 902    NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925    NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946    NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947    NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951    NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# 937             False  Client Services
# ...

# %%
df[df["First Name"]=="Sameer"]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
df.drop("First Name",axis="columns")
# Out:
#      Gender Start Date Last Login Time  Salary  Bonus % Senior Management  \
# 101    Male  2/17/2012        10:20 AM   61602   11.849              True
# 327    Male  1/29/1994         6:48 PM   58755    5.097              True
# 440    Male  7/22/1990         2:53 PM   52119   11.343              True
# 937     NaN  1/22/1986         7:39 PM   63126   18.424             False
# 137    Male  5/21/2011         1:45 AM   95327   15.120             False
# ..      ...        ...             ...     ...      ...               ...
# 902    Male  5/23/2001         7:52 PM  103877    6.322               NaN
# 925  Female  8/23/2000         4:19 PM   95866   19.388               NaN
# 946  Female  9/15/1985         1:50 AM  133472   16.941               NaN
# 947    Male  7/30/2012         3:07 PM  107351    5.329               NaN
# 951  Female  9/14/2010         5:19 AM  143638    9.662               NaN
#
#                 Team
# 101        Marketing
# 327        Marketing
# ...

# %%
df22=df.pop("Team")

# %%
df["Team"]=df22

# %%
df
# Out:
# C:\Users\miles\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\lib\pretty.py:778: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\miles\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\formatters.py:342: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 101 to 951
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 102.6+ KB

# %%
import pandas as pd
df=pd.read_csv("EmployeesInfo.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df=df.drop_duplicates(subset=["First Name"],keep="first")

# %%
df=df.fillna("Unknown")

# %%
df.pivot(index="First Name",columns="Team", values="Salary").fillna("-")
# Out:
# Team       Business Development Client Services Distribution Engineering  \
# First Name
# Aaron                         -               -            -           -
# Adam                          -               -      95327.0           -
# Alan                          -               -            -           -
# Albert                        -               -            -     67827.0
# Alice                         -               -            -           -
# ...                         ...             ...          ...         ...
# Walter                        -               -            -           -
# Wanda                         -               -            -           -
# Wayne                         -               -     102652.0           -
# William                       -               -            -           -
# Willie                        -               -            -           -
#
# Team         Finance Human Resources    Legal Marketing Product Sales Unknown
# ...

# %%
df.pivot(index="Team",columns="First Name", values="Salary").fillna("-")
# Out:
# First Name              Aaron     Adam     Alan   Albert    Alice   Amanda  \
# Team
# Business Development        -        -        -        -        -        -
# Client Services             -        -        -        -        -        -
# Distribution                -  95327.0        -        -        -  80803.0
# Engineering                 -        -        -  67827.0        -        -
# Finance                     -        -  40341.0        -  51395.0        -
# Human Resources             -        -        -        -        -        -
# Legal                       -        -        -        -        -        -
# Marketing             61602.0        -        -        -        -        -
# Product                     -        -        -        -        -        -
# Sales                       -        -        -        -        -        -
# Unknown                     -        -        -        -        -        -
#
# ...

# %%
melted_df = df.melt(id_vars=['Team'], value_vars=['Salary'])
print(melted_df)
# Out:
#                      Team variable   value
# 0               Marketing   Salary   97308
# 1                     NaN   Salary   61933
# 2                 Finance   Salary  130590
# 3                 Finance   Salary  138705
# 4         Client Services   Salary  101004
# ..                    ...      ...     ...
# 995          Distribution   Salary  132483
# 996               Finance   Salary   42392
# 997               Product   Salary   96914
# 998  Business Development   Salary   60500
# 999                 Sales   Salary  129949
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df=df.dropna()

# %%
df[df["First Name"].str.startswith("R") | df["First Name"].str.endswith("y")]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 13        Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 3                True               Finance
# 4                True       Client Services
# ...
